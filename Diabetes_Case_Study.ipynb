# %%
# Importing some Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
import warnings
warnings.filterwarnings('ignore')

# %%
# prompt: write python code to read csv file from github

import pandas as pd

url = 'https://raw.githubusercontent.com/ksingh9398/DATA/main/diabetes.csv'
df = pd.read_csv(url)
df.head(1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Pregnancies'].plot(kind='hist', bins=20, title='Pregnancies')
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# CHECK NULL VALUES
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# there is no any null values are present

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(df.isnull(),color='blue')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df['Outcome'].unique()
# Out:
# array([1, 0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# change data type float to int
df['BMI']=df['BMI'].astype('int')

# %%
df['DiabetesPedigreeFunction']=df['DiabetesPedigreeFunction'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    int64
#  6   DiabetesPedigreeFunction  768 non-null    int64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: int64(9)
# memory usage: 54.1 KB

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            6      148             72             35        0   33
# 1            1       85             66             29        0   26
# 2            8      183             64              0        0   23
# 3            1       89             66             23       94   28
# 4            0      137             40             35      168   43
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                         0   50        1
# 1                         0   31        0
# 2                         0   32        1
# 3                         0   21        0
# 4                         2   33        1

# %%
for i in df.columns:
    print(i)
    print(df[i].unique())
# Out:
# Pregnancies
# [ 6  1  8  0  5  3 10  2  4  7  9 11 13 15 17 12 14]
# Glucose
# [148  85 183  89 137 116  78 115 197 125 110 168 139 189 166 100 118 107
#  103 126  99 196 119 143 147  97 145 117 109 158  88  92 122 138 102  90
#  111 180 133 106 171 159 146  71 105 101 176 150  73 187  84  44 141 114
#   95 129  79   0  62 131 112 113  74  83 136  80 123  81 134 142 144  93
#  163 151  96 155  76 160 124 162 132 120 173 170 128 108 154  57 156 153
#  188 152 104  87  75 179 130 194 181 135 184 140 177 164  91 165  86 193
#  191 161 167  77 182 157 178  61  98 127  82  72 172  94 175 195  68 186
#  198 121  67 174 199  56 169 149  65 190]
# BloodPressure
# [ 72  66  64  40  74  50   0  70  96  92  80  60  84  30  88  90  94  76
#   82  75  58  78  68 110  56  62  85  86  48  44  65 108  55 122  54  52
#   98 104  95  46 102 100  61  24  38 106 114]
# SkinThickness
# [35 29  0 23 32 45 19 47 38 30 41 33 26 15 36 11 31 37 42 25 18 24 39 27
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.iloc[450:460]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 450            1       82             64             13       95   21
# 451            2      134             70              0        0   28
# 452            0       91             68             32      210   39
# 453            2      119              0              0        0   19
# 454            2      100             54             28      105   37
# 455           14      175             62             30        0   33
# 456            1      135             54              0        0   26
# 457            5       86             68             28       71   30
# 458           10      148             84             48      237   37
# 459            9      134             74             33       60   25
#
#      DiabetesPedigreeFunction  Age  Outcome
# 450                         0   23        0
# 451                         0   23        1
# 452                         0   25        0
# ...

# %%
df.head(1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            6      148             72             35        0   33
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                         0   50        1

# %%
np.mean(df['Age'])
# Out:
# 33.240885416666664

# %%
sns.heatmap(df.isnull(),cmap='cool_r')
# Out:
# <Axes: >

# %%
df.iloc[488,:]
# Out:
# Pregnancies                  4
# Glucose                     99
# BloodPressure               72
# SkinThickness               17
# Insulin                      0
# BMI                         25
# DiabetesPedigreeFunction     0
# Age                         28
# Outcome                      0
# Name: 488, dtype: int64

# %%
# Checking numberof unique values in each column
df.nunique().to_frame('No. of unique values')
# Out:
#                           No. of unique values
# Pregnancies                                 17
# Glucose                                    136
# BloodPressure                               47
# SkinThickness                               51
# Insulin                                    186
# BMI                                         40
# DiabetesPedigreeFunction                     3
# Age                                         52
# Outcome                                      2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_28['No. of unique values'].plot(kind='hist', bins=20, title='No. of unique values')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            6      148             72             35        0   33
# 1            1       85             66             29        0   26
# 2            8      183             64              0        0   23
# 3            1       89             66             23       94   28
# 4            0      137             40             35      168   43
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                         0   50        1
# 1                         0   31        0
# 2                         0   32        1
# 3                         0   21        0
# 4                         2   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.548177                  0.071615   33.240885    0.348958
# std      7.860602                  0.277494   11.760232    0.476951
# ...

# %%
# Visulize the number of Churned customers
ax=sns.countplot(x='Age',data=df)

# %%
sns.pairplot(df)

# %%
df.head(1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            6      148             72             35        0   33
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                         0   50        1

# %%
# Visulizing the count of Partner
print(df['Glucose'].value_counts())
ax=sns.countplot(x='Glucose',data=df)
plt.show()
# Out:
# Glucose
# 99     17
# 100    17
# 111    14
# 129    14
# 125    14
#        ..
# 191     1
# 177     1
# 44      1
# 62      1
# 190     1
# Name: count, Length: 136, dtype: int64

# %%
sns.stripplot(x='Age',y='BMI',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='BMI'>

# %%
sns.stripplot(x='Age',y='SkinThickness',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='SkinThickness'>

# %%
# Checking Outliers
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(df['Insulin'])
# Out:
# <Axes: ylabel='Insulin'>

# %%
df.shape
# Out:
# (768, 9)

# %%
# prompt: write python code to check skewness of df

df.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.384770
# DiabetesPedigreeFunction    4.039350
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %%
df['BMI']=np.cbrt(df['BMI'])

# %%
df['BloodPressure']=np.cbrt(df['BloodPressure'])

# %%
df.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -3.882767
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -5.068816
# DiabetesPedigreeFunction    4.039350
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %%
sns.distplot(df['BloodPressure'], color='m',kde_kws={'shade':True}, hist=False)
plt.show()

# %%
import sklearn

# %%
# Encoding categorical columns using OrdinalEncoder
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin       BMI  \
# 0              6      148       4.160168             35        0  3.207534
# 1              1       85       4.041240             29        0  2.962496
# 2              8      183       4.000000              0        0  2.843867
# 3              1       89       4.041240             23       94  3.036589
# 4              0      137       3.419952             35      168  3.503398
# ..           ...      ...            ...            ...      ...       ...
# 763           10      101       4.235824             48      180  3.174802
# 764            2      122       4.121285             27        0  3.301927
# 765            5      121       4.160168             23      112  2.962496
# 766            1      126       3.914868              0        0  3.107233
# 767            1       93       4.121285             31        0  3.107233
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.head(1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin       BMI  \
# 0            6      148       4.160168             35        0  3.207534
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                         0   50        1

# %%
x=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin       BMI  \
# 0            6      148       4.160168             35        0  3.207534
# 1            1       85       4.041240             29        0  2.962496
# 2            8      183       4.000000              0        0  2.843867
# 3            1       89       4.041240             23       94  3.036589
# 4            0      137       3.419952             35      168  3.503398
#
#    DiabetesPedigreeFunction  Age
# 0                         0   50
# 1                         0   31
# 2                         0   32
# 3                         0   21
# 4                         2   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639947  0.848324       0.217680       0.907270 -0.692891  0.214777
# 1      -0.844885 -1.123396       0.085266       0.530902 -0.692891 -0.345329
# 2       1.233880  1.943724       0.039349      -1.288212 -0.692891 -0.616490
# 3      -0.844885 -0.998208       0.085266       0.154533  0.123302 -0.175969
# 4      -1.141852  0.504055      -0.606477       0.907270  0.765836  0.891059
# ..           ...       ...            ...            ...       ...       ...
# 763     1.827813 -0.622642       0.301916       1.722735  0.870031  0.139958
# 764    -0.547919  0.034598       0.174389       0.405445 -0.692891  0.430539
# 765     0.342981  0.003301       0.217680       0.154533  0.279594 -0.345329
# 766    -0.844885  0.159787      -0.055437      -1.288212 -0.692891 -0.014492
# 767    -0.844885 -0.873019       0.174389       0.656358 -0.692891 -0.014492
#
#      DiabetesPedigreeFunction       Age
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
# RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
# Checking accuracy for RandomForestClasifier
RFC= RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC=RFC.predict(x_test)
print(accuracy_score(y_test, predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.7705627705627706
# [[139  18]
#  [ 35  39]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       157
#            1       0.68      0.53      0.60        74
#
#     accuracy                           0.77       231
#    macro avg       0.74      0.71      0.72       231
# weighted avg       0.76      0.77      0.76       231

# %%
# NAVIN SINGH
